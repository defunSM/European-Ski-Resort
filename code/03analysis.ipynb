# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
# dataset
df = pd.read_csv('../data/raw/European_Ski_Resorts.csv')

# %%
# split data into "X" and "y" set
X = df[['DayPassPriceAdult']]
y = df['DifficultSlope']
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
df
# Out:
#        #                                             Resort          Country  \
# 0      1                              Alpendorf (Ski amedé)          Austria
# 1      2  Soldeu-Pas de la Casa/​Grau Roig/​El Tarter/​C...          Andorra
# 2      3                              Oberau (Wildschönau)          Austria
# 3      4                                     Dachstein West          Austria
# 4      5                                        Rosa Khutor  Southern Russia
# ..   ...                                                ...              ...
# 371  372                          Montgenèvre (Via Lattea)           France
# 372  373                          Sauze d’Oulx (Via Lattea)            Italy
# 373  374             Gressoney - La-Trinite (Monterosa Ski)            Italy
# 374  375                          Champoluc (Monterosa Ski)            Italy
# 375  376                                         Zauchensee          Austria
#
# ...

# %%
# TODO: make linear regression object
reg = LinearRegression()


# fit model to data
reg.fit(X_train,y_train)

# Print the coefficients and intercept
print("Coefficients:", reg.coef_)
print("Intercept:", reg.intercept_)
# Out:
# Coefficients: [0.68777641]
# Intercept: -15.958998504802326

# %%
# TODO: score model on X_train & y_train
r2 = reg.score(X_train, y_train)
print("R^2:", r2)

# TODO: generate predictions on X_test
y_pred = reg.predict(X_test)
# score MSE 
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# R^2: 0.22613455241770142
# MSE: 180.5211582914469

# %%
# TODO: You can use the trained model (reg) to make predictions on new data

reg.predict(X_train)
# Out:
# array([ 17.74204566,  18.42982207,  11.55205796,  19.11759849,
#         19.8053749 ,  16.36649284,   8.1131759 ,  14.3031636 ,
#         11.55205796,  10.86428155,  17.05426925,  17.74204566,
#         12.23983437, -15.9589985 ,  13.61538719,   6.04984667,
#          1.23541178,  17.05426925,  25.9953626 ,  12.92761078,
#         25.9953626 ,  12.23983437,  18.42982207,  15.67871643,
#         14.99094002,   9.48872872,  15.67871643,  16.36649284,
#          5.36207025,  17.05426925,  18.42982207,  10.17650514,
#         13.61538719,   8.80095231,  15.67871643,  13.61538719,
#         14.3031636 ,  14.3031636 ,   8.1131759 ,  17.74204566,
#         21.86870413,  16.36649284,  -3.5790231 ,  15.67871643,
#         22.55648054,  -2.89124668,   8.1131759 ,  17.05426925,
#         14.3031636 ,  25.9953626 ,   8.1131759 ,  18.42982207,
#         14.99094002,   9.48872872,   8.80095231,   5.36207025,
#         16.36649284,  14.99094002,  12.92761078,  11.55205796,
# ...

# %%
# serialize and save the model
pickle.dump(reg, open("code/model/saved_models/analysis.sav", 'wb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/devenie/Desktop/TKH Projects/European-Ski-Resort/code/03analysis.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/European-Ski-Resort/code/03analysis.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # serialize and save the model
# ----> <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/European-Ski-Resort/code/03analysis.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> pickle.dump(reg, open("code/model/saved_models/analysis.sav", 'wb'))
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
# ...
